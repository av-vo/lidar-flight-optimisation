# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../logs/ts.tsv', sep='\t')

# %%
plt.rc('figure', figsize=(7, 4))

fig, ax = plt.subplots(1, 1, 
                         #sharey=True,
                         #sharex = 'col'
                         #constrained_layout=True
                        )

ax.plot(df['score'], linewidth=0, marker='+')
