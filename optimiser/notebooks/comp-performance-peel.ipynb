# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../logs/performance-peel.csv')

# %%
df
# Out:
#     num_executors  num_cores  runtime         S         E  Unnamed: 5  \
# 0               1          1   129.68       NaN       NaN         NaN
# 1               2          1    83.03  1.561845  0.780923    1.561845
# 2               4          1    46.80  2.770940  0.692735    2.770940
# 3               8          1    31.15  4.163082  0.520385    4.163082
# 4              16          1    26.73  4.851478  0.303217    4.851478
# 5               1          2    77.14       NaN       NaN    1.681099
# 6               2          2    48.59  1.587569  0.793785    2.668862
# 7               4          2    30.11  2.561940  0.640485    4.306875
# 8               8          2    27.95  2.759928  0.344991    4.639714
# 9              16          2    22.18  3.477908  0.217369    5.846709
# 10              1          4    51.96       NaN       NaN    2.495766
# 11              2          4    31.81  1.633449  0.816724    4.076705
# 12              4          4    25.30  2.053755  0.513439    5.125692
# 13              8          4    19.75  2.630886  0.328861    6.566076
# 14             16          4    20.75  2.504096  0.156506    6.249639
# 15              1          8    32.27       NaN       NaN    4.018593
# 16              2          8    28.00  1.152500  0.576250    4.631429
# 17              4          8    23.27  1.386764  0.346691    5.572841
# 18              8          8    19.05  1.693963  0.211745    6.807349
# 19             16          8    17.22  1.873984  0.117124    7.530778
# 20              1         16    38.13       NaN       NaN    3.400997
# 21              2         16    45.68  0.834720  0.417360    2.838879
# 22              4         16    21.24  1.795198  0.448799    6.105461
# 23              8         16    31.94  1.193801  0.149225    4.060113
# 24             16         16    18.89  2.018528  0.126158    6.865008
#
#     Unnamed: 6
# 0          NaN
# 1     0.780923
# 2     0.692735
# 3     0.520385
# 4     0.303217
# 5     0.840550
# 6     0.667215
# 7     0.538359
# 8     0.289982
# 9     0.182710
# 10    0.623941
# 11    0.509588
# 12    0.320356
# 13    0.205190
# 14    0.097651
# 15    0.502324
# 16    0.289464
# 17    0.174151
# 18    0.106365
# 19    0.058834
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN

# %%
plt.rc('figure', figsize=(5, 4))

fig, ax = plt.subplots(1, 1, 
                         #sharey=True,
                         #sharex = 'col'
                         constrained_layout=True
                        )

num_cores=1
ax.plot(df[df['num_cores']==num_cores]['num_executors'], 
        df[df['num_cores']==num_cores]['runtime'],
        linestyle='solid',
        color='black',
        label=str(num_cores) + ' core'
       )

num_cores*=2
ax.plot(df[df['num_cores']==num_cores]['num_executors'], 
        df[df['num_cores']==num_cores]['runtime'],
        linestyle='dashdot',
        color='black',
        label=str(num_cores) + ' cores'
       )

num_cores*=2
ax.plot(df[df['num_cores']==num_cores]['num_executors'], 
        df[df['num_cores']==num_cores]['runtime'],
        linestyle='dashed',
        color='black',
        label=str(num_cores) + ' cores'
       )

num_cores*=2
ax.plot(df[df['num_cores']==num_cores]['num_executors'], 
        df[df['num_cores']==num_cores]['runtime'],
        linestyle='dotted',
        color='black',
        label=str(num_cores) + ' cores'
       )


plt.plot([], [], ' ', label='per executor')
    
#ax.set_title('Computational performance of the distributed evaluator')
ax.set_xlabel('Number of executors')
ax.set_ylabel('Runtime (sec)')

ax.set_xticks([1, 2, 4, 8, 16])
ax.grid(color='black', ls = '--', lw = 0.2)

#ax.set_yscale("log")
#ax.grid()
ax.legend()

plt.savefig('peel.svg')
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [markdown]
# Peel
