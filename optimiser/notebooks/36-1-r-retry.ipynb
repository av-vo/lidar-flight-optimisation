#
#           31        32        33        34        35        36
# 0   14718748  14852374  14641481  14837465  14971091  14760198
# 1   15671039  15620507  15045844  15542920  15148311  14938901
# 2   16213712  15658594  15547328  16103999  14852374  15658144
# 3   16164165  14951318  16005291  16406251  15159758  15543157
# 4   15179537  16231478  15656676  16155482  16401453  15658867
# 5   15671075  16008561  14722576  16474328  16063563  16060682
# 6   14883783  15997532  15453493  15593509  15424697  15402222
# 7   15115253  16437583  15267000  14656661  15651672  16067661
# 8   15115218  16365307  16476915  15626458  15906427  16442842
# 9   14753031  14888199  14882956  14945416  16365307  16302452
# 10  15675908  16306218  14811356  14942992  16428670  15210364
# 11  15683733  14945255  15458621  15654107  14685045  16323886
# 12  15188131  15694613  15013031  14820902  14861249  15223101
# 13  15201625  15932613  14724893  15134263  16403722  16397273
# 14  16258544  14999710  15134263  14629599  14761174  16081005
# 15  16055971  16484768  14763180  15179621  14955919  14949195
# 16  14829612  15134821  16513811  14661195  14763180  14957322
#
# [17 rows x 36 columns]

# %%
#df.to_csv('../logs/16-2-reverse.tsv', sep='\t')

# %%
plt.rc('figure', figsize=(7, 3))

fig, ax = plt.subplots(1, 1, 
                         #sharey=True,
                         #sharex = 'col'
                         #constrained_layout=True
                        )

parts = ax.violinplot(data, vert=True, showmedians=True, showmeans=False, showextrema=False, widths=.75, bw_method='silverman')

for pc in parts['bodies']:
    pc.set_facecolor('#D43F3A')
    #pc.set_edgecolor('black')
    pc.set_alpha(.6)
    
maxPerGen = np.median(data, axis=0)
plt.plot(range(1,1+len(maxPerGen)),maxPerGen, linestyle='--', color='r', linewidth=.5, marker='.')

# %%
d = (data - 14000000)/14000000*100

# %%
plt.rc('figure', figsize=(7, 3))

fig, ax = plt.subplots(1, 1, 
                         #sharey=True,
                         #sharex = 'col'
                         #constrained_layout=True
                        )

parts = ax.violinplot(d, vert=True, showmedians=True, showmeans=False, showextrema=False, widths=.75, bw_method='silverman')

# %%
plt.rc('figure', figsize=(5, 5))

fig, ax = plt.subplots(1, 1, 
                         #sharey=True,
                         #sharex = 'col'
                         #constrained_layout=True
                        )

sns.set_theme(style="whitegrid")
sns.violinplot(data=data, linewidth=1, gridsize=18, scale='count', bw='scott', width=1, inner='box', split=False, dodge=True, orient='v', color='#eeeeee', palette=None, saturation=0.75, ax=ax)


median = np.median(data, axis=0)
plt.plot(range(0,len(median)), median, linestyle='dashed', color='r', linewidth=1, marker='.')
